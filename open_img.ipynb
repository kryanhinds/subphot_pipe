# %%
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.visualization import SqrtStretch,simple_norm
from astropy import visualization

# %%
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-10-04_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-10-10_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-10-15_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-10-17_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-11-13_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-11-14_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2021-12-28_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2022-02-07_wcs.fits'
name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2022-02-08_wcs.fits' # weird
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_g_SDSS_2022-08-28_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2021-10-10_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2021-10-17_wcs.fits' #weird
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2021-11-13_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2021-12-29_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2022-02-13_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2022-08-28_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_i_SDSS_2022-09-21_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_r_SDSS_2021-10-10_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_r_SDSS_2021-10-17_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_r_SDSS_2021-11-13_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_r_SDSS_2021-12-29_wcs.fits'
# name = '/Volumes/K_H_HD_2TB/phot_data/SteveSData/SN2021yfj_2/ZTF21abzbmhz_r_SDSS_2022-08-28_wcs.fits'

# %%
hdu = fits.open(name)

data0 = hdu[0].data
data1 = hdu[1].data
print(hdu[0].data)
# fig, ax = plt.subplots(1, 1, figsize=(10, 5))
fig = plt.figure(figsize=(10, 10))
# norm = ImageNormalize(data0, interval=visualization.ZScaleInterval(),stretch=visualization.SqrtStretch())
lim1,lim2 = visualization.ZScaleInterval().get_limits(data1)
plt.title(name.split('/')[-1])
# try:ax[0].imshow(data0, cmap='gray', norm=norm)
# except:pass
plt.imshow(data1, cmap='gray', vmin=lim1, vmax=lim2)
plt.show()
# Out:
# None

# %%
new_fits_hdu = fits.PrimaryHDU()
new_fits_hdu.data = data1
new_fits_hdu.header = hdu[1].header
new_fits_hdu.writeto(name.replace('.fits','1.fits').replace('SN2021yfj_2','SN2021yfj_1'), overwrite=True)
